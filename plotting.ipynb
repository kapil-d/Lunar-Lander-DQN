# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def moving_average(data, window_size):
    return np.convolve(data, np.ones(window_size) / window_size, mode='valid')

def plot_experiment(filename, algorithm_name, wind_strength, window_size=100):
    rewards = np.loadtxt(filename)
    
    rewards_moving_avg = moving_average(rewards, window_size)
    episodes = np.arange(len(rewards_moving_avg)) + window_size - 1

    # Plot the moving average
    #plt.figure()
    plt.plot(episodes, rewards_moving_avg, label=f'{algorithm_name}, Wind Speed = {wind_strength}')
    plt.xlabel('Episode')
    plt.ylabel('Reward')

    #plt.show()

# %%
# plot_experiment('experiments/env_wind_0_DQN_rewards.txt', 'DQN', 0)
# plot_experiment('experiments/env_wind_1_DQN_rewards.txt', 'DQN', 5)
# plot_experiment('experiments/env_wind_2_DQN_rewards.txt', 'DQN', 10)
# plot_experiment('experiments/env_wind_3_DQN_rewards.txt', 'DQN', 15)
# plot_experiment('experiments/env_wind_4_DQN_rewards.txt', 'DQN', 20)

plot_experiment('experiments/env_wind_0_DDQN_rewards.txt', 'DDQN', 0)
plot_experiment('experiments/env_wind_1_DDQN_rewards.txt', 'DDQN', 5)
plot_experiment('experiments/env_wind_2_DDQN_rewards.txt', 'DDQN', 10)
plot_experiment('experiments/env_wind_3_DDQN_rewards.txt', 'DDQN', 15)
plot_experiment('experiments/env_wind_4_DDQN_rewards.txt', 'DDQN', 20)

# plot_experiment('experiments/env_wind_0_DuelingDQN_rewards.txt', 'Dueling DQN', 0)
# plot_experiment('experiments/env_wind_1_DuelingDQN_rewards.txt', 'Dueling DDQN', 5)
# plot_experiment('experiments/env_wind_2_DuelingDQN_rewards.txt', 'Dueling DDQN', 10)
# plot_experiment('experiments/env_wind_3_DuelingDQN_rewards.txt', 'Dueling DDQN', 15)




plt.grid()
plt.legend()
plt.show()
